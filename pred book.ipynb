# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline

# %%
df=pd.read_csv("F:\\insurance premium pred\\insurance\\insurance.csv")
df
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 0      19  female  27.9         0    yes  southwest  16884.92
# 1      18    male  33.8         1     no  southeast   1725.55
# 2      28    male  33.0         3     no  southeast   4449.46
# 3      33    male  22.7         0     no  northwest  21984.47
# 4      32    male  28.9         0     no  northwest   3866.86
# ...   ...     ...   ...       ...    ...        ...       ...
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
# 1337   61  female  29.1         0    yes  northwest  29141.36
#
# [1338 rows x 7 columns]

# %%
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   expenses  1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# expenses    0
# dtype: int64

# %%
df.describe(include='all')
# Out:
#                 age   sex          bmi     children smoker     region  \
# count   1338.000000  1338  1338.000000  1338.000000   1338       1338
# unique          NaN     2          NaN          NaN      2          4
# top             NaN  male          NaN          NaN     no  southeast
# freq            NaN   676          NaN          NaN   1064        364
# mean      39.207025   NaN    30.665471     1.094918    NaN        NaN
# std       14.049960   NaN     6.098382     1.205493    NaN        NaN
# min       18.000000   NaN    16.000000     0.000000    NaN        NaN
# 25%       27.000000   NaN    26.300000     0.000000    NaN        NaN
# 50%       39.000000   NaN    30.400000     1.000000    NaN        NaN
# 75%       51.000000   NaN    34.700000     2.000000    NaN        NaN
# max       64.000000   NaN    53.100000     5.000000    NaN        NaN
#
#             expenses
# count    1338.000000
# unique           NaN
# top              NaN
# freq             NaN
# ...

# %%
duplicates = df[df.duplicated()]
if duplicates.empty:
    print("No duplicates found.")
else:
    print("Duplicates found:")
    print(duplicates)
# Out:
# Duplicates found:
#      age   sex   bmi  children smoker     region  expenses
# 581   19  male  30.6         0     no  northwest   1639.56

# %%
df.describe(include='all')
# Out:
#                 age   sex          bmi     children smoker     region  \
# count   1338.000000  1338  1338.000000  1338.000000   1338       1338
# unique          NaN     2          NaN          NaN      2          4
# top             NaN  male          NaN          NaN     no  southeast
# freq            NaN   676          NaN          NaN   1064        364
# mean      39.207025   NaN    30.665471     1.094918    NaN        NaN
# std       14.049960   NaN     6.098382     1.205493    NaN        NaN
# min       18.000000   NaN    16.000000     0.000000    NaN        NaN
# 25%       27.000000   NaN    26.300000     0.000000    NaN        NaN
# 50%       39.000000   NaN    30.400000     1.000000    NaN        NaN
# 75%       51.000000   NaN    34.700000     2.000000    NaN        NaN
# max       64.000000   NaN    53.100000     5.000000    NaN        NaN
#
#             expenses
# count    1338.000000
# unique           NaN
# top              NaN
# freq             NaN
# ...

# %%
df=df.drop_duplicates()

# %%
df.shape
# Out:
# (1337, 7)

# %% [markdown]
# # Exploratory Data Analysis

# %%
x_axis=['age','bmi','children','expenses']
for x in x_axis:
    fig,axes= plt.subplots(1,2,figsize=(18,4))
    sns.distplot(df[x],ax=axes[0],kde=False)
    sns.boxplot(df[x],ax=axes[1], orient='h', showmeans=True, color="pink")
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_5608\1126262410.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[x],ax=axes[0],kde=False)
# C:\Users\hp\AppData\Local\Temp\ipykernel_5608\1126262410.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
print("\nPairplot to visualize relationships between numerical features:")
sns.pairplot(df)
plt.show()

# Countplot for categorical features
print("\nCountplot for categorical features:")
fig, axes = plt.subplots(2, 2, figsize=(12, 10))
sns.countplot(ax=axes[0, 0], x='sex', data=df)
sns.countplot(ax=axes[0, 1], x='smoker', data=df)
sns.countplot(ax=axes[1, 0], x='region', data=df)
sns.countplot(ax=axes[1, 1], x='children', data=df)
plt.show()

# Correlation heatmap
# print("\nCorrelation heatmap:")
# plt.figure(figsize=(10, 8))
# sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
# plt.show()
# Out:
# Pairplot to visualize relationships between numerical features:
# F:\anacon\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# Countplot for categorical features:

# %%
print(df.sex.unique())
print(df.smoker.unique())
print(df.region.unique())
# Out:
# ['female' 'male']
# ['yes' 'no']
# ['southwest' 'southeast' 'northwest' 'northeast']

# %%
df['sex']=df.sex.map({'female':0, 'male':1})
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_5608\3411755011.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sex']=df.sex.map({'female':0, 'male':1})

# %%
df['smoker']=df.smoker.map({'yes':1, 'no':0})
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_5608\749255708.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['smoker']=df.smoker.map({'yes':1, 'no':0})

# %%
df['region']=df.region.map({'southwest':1, 'southeast':2,'northwest':3,'northeast':4})
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_5608\1320789238.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['region']=df.region.map({'southwest':1, 'southeast':2,'northwest':3,'northeast':4})

# %%
df
# Out:
#       age  sex   bmi  children  smoker  region  expenses
# 0      19    0  27.9         0       1       1  16884.92
# 1      18    1  33.8         1       0       2   1725.55
# 2      28    1  33.0         3       0       2   4449.46
# 3      33    1  22.7         0       0       3  21984.47
# 4      32    1  28.9         0       0       3   3866.86
# ...   ...  ...   ...       ...     ...     ...       ...
# 1333   50    1  31.0         3       0       3  10600.55
# 1334   18    0  31.9         0       0       4   2205.98
# 1335   18    0  36.9         0       0       2   1629.83
# 1336   21    0  25.8         0       0       1   2007.95
# 1337   61    0  29.1         0       1       3  29141.36
#
# [1337 rows x 7 columns]

# %% [markdown]
# # split

# %%
x=df.drop(['expenses'],axis=1)

# %%
x.head()
# Out:
#    age  sex   bmi  children  smoker  region
# 0   19    0  27.9         0       1       1
# 1   18    1  33.8         1       0       2
# 2   28    1  33.0         3       0       2
# 3   33    1  22.7         0       0       3
# 4   32    1  28.9         0       0       3

# %%
y=df[['expenses']]

# %%
y.head()
# Out:
#    expenses
# 0  16884.92
# 1   1725.55
# 2   4449.46
# 3  21984.47
# 4   3866.86

# %%
x
# Out:
#       age  sex   bmi  children  smoker  region
# 0      19    0  27.9         0       1       1
# 1      18    1  33.8         1       0       2
# 2      28    1  33.0         3       0       2
# 3      33    1  22.7         0       0       3
# 4      32    1  28.9         0       0       3
# ...   ...  ...   ...       ...     ...     ...
# 1333   50    1  31.0         3       0       3
# 1334   18    0  31.9         0       0       4
# 1335   18    0  36.9         0       0       2
# 1336   21    0  25.8         0       0       1
# 1337   61    0  29.1         0       1       3
#
# [1337 rows x 6 columns]

# %% [markdown]
# # outliers

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import HuberRegressor
from scipy.stats.mstats import winsorize
from sklearn.metrics import r2_score
import numpy as np

methods = {
    'No Transformation': y,
    'Log Transformation': np.log1p(y),  # Log transformation
    'Robust Regression': HuberRegressor().fit(x, y).predict(x)  # Robust regression
}

# Initialize Random Forest Regressor
rf = RandomForestRegressor(random_state=42)

# Perform cross-validation for each method
results = {}
for name, y_transformed in methods.items():
    mse_scores = cross_val_score(rf, x, y_transformed, cv=5, scoring='neg_mean_squared_error')
    mse_mean = -mse_scores.mean()  # Convert negative MSE scores to positive
    r2_scores = cross_val_score(rf, x, y_transformed, cv=5, scoring='r2')
    r2_mean = r2_scores.mean()
    results[name] = {'MSE': mse_mean, 'R2': r2_mean}

# Print results
for name, metrics in results.items():
    print(f"{name}: Mean Squared Error = {metrics['MSE']}, R2 Score = {metrics['R2']}")
# Out:
# F:\anacon\Lib\site-packages\sklearn\utils\validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# F:\anacon\Lib\site-packages\sklearn\linear_model\_huber.py:342: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# F:\anacon\Lib\site-packages\sklearn\base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# ...

# %%
yo=np.log1p(y)
yo
# Out:
#        expenses
# 0      9.734235
# 1      7.453880
# 2      8.400763
# 3      9.998137
# 4      8.260457
# ...         ...
# 1333   9.268755
# 1334   7.699380
# 1335   7.396844
# 1336   7.605367
# 1337  10.279948
#
# [1337 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split 
xtrain,xtest,ytrain,ytest=train_test_split(x,yo,test_size=0.2,random_state=42)

# %%
print(xtrain.shape)
xtest.shape
# Out:
# (1069, 6)
# (268, 6)

# %% [markdown]
# # model training

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.metrics import mean_squared_error, r2_score

# %%
models = {
    'Linear Regression': LinearRegression(),
    'Random Forest': RandomForestRegressor(random_state=42),
    'Gradient Boosting': GradientBoostingRegressor(random_state=42)
}

# Train and evaluate each model
for name, model in models.items():
    print("Training", name)
    model.fit(xtrain, ytrain)
    ypred = model.predict(xtest)
    mse = mean_squared_error(ytest, ypred)
    r2 = r2_score(ytest, ypred)
    print("Mean Squared Error:", mse)
    print("R-squared Score:", r2)
    print("="*50)
# Out:
# Training Linear Regression
# Mean Squared Error: 0.1598102499700184
# R-squared Score: 0.8277698714998303
# ...
# Training Random Forest
# F:\anacon\Lib\site-packages\sklearn\base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Mean Squared Error: 0.1432750293654241
# R-squared Score: 0.8455901500491861
# ...
# Training Gradient Boosting
# Mean Squared Error: 0.10910679319982869
# R-squared Score: 0.8824138187846313
# ...
# F:\anacon\Lib\site-packages\sklearn\ensemble\_gb.py:424: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
data={
    'age':[50,18,61],
    'sex':[1,0,0],
    'bmi':[31,31.9,29.1],
    'children':[3,0,0],
    'smoker':[0,0,1],
    'region':[3,4,3]
}
# 50	male	31.0	3	no	northwest	10600.55
# 18	female	31.9	0	no	northeast	2205.98
# 61	female	29.1	0	yes	northwest	29141.36
# ['female' 'male']
# ['yes' 'no']
# ['southwest' 'southeast' 'northwest' 'northeast']
newdf=pd.DataFrame(data,index=[0,1,2])
newdf
# Out:
#    age  sex   bmi  children  smoker  region
# 0   50    1  31.0         3       0       3
# 1   18    0  31.9         0       0       4
# 2   61    0  29.1         0       1       3

# %%
modela = models['Random Forest']
pred=np.expm1(modela.predict(newdf))
pred
# Out:
# array([10887.15893273,  2288.20610409, 28696.88841555])

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {
    'n_estimators': [300, 400, 500],  # Number of trees in the forest
    'max_depth': [None, 10, 20, 30],    # Maximum depth of the trees
    'min_samples_split': [6, 8, 10],    # Minimum number of samples required to split an internal node
    'min_samples_leaf': [5, 6, 8]       # Minimum number of samples required to be at a leaf node
}

rf = RandomForestRegressor(random_state=42)
grid_search = GridSearchCV(estimator=rf, param_grid=param_grid, cv=5, scoring='neg_mean_squared_error', n_jobs=-1)
grid_search.fit(xtrain, ytrain)
print("Best hyperparameters:", grid_search.best_params_)
best_model = grid_search.best_estimator_
ypred = best_model.predict(xtest)


# param_grid = {
#     'learning_rate': [0.01, 0.05, 0.1, 0.5, 1],
#     'n_estimators': [50, 100, 150, 200, 250, 300],
#     'max_depth': [2, 3, 4, 5, 6, 7, 8]
# }
# hpt_model = GradientBoostingRegressor()
# grid_search = GridSearchCV(hpt_model, param_grid, cv=10, n_jobs=-1, verbose=1)
# grid_search.fit(xtrain, ytrain)
# print(grid_search.best_params_)
# Out:
# F:\anacon\Lib\site-packages\sklearn\base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Best hyperparameters: {'max_depth': None, 'min_samples_leaf': 8, 'min_samples_split': 6, 'n_estimators': 400}

# %%
from sklearn.metrics import mean_absolute_error
best_params = grid_search.best_params_
final_model = RandomForestRegressor(**best_params,random_state=42)
final_model.fit(xtrain, ytrain)
final_model_score = final_model.score(xtest, ytest)
mse = mean_squared_error(ytest, ypred)
mae = mean_absolute_error(ytest, ypred)
r2 = r2_score(ytest, ypred)

print("Mean Squared Error (MSE):", mse)
print("Mean Absolute Error (MAE):", mae)
print("R-squared (R2) Score:", r2)
# Out:
# F:\anacon\Lib\site-packages\sklearn\base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Mean Squared Error (MSE): 0.10765068840980326
# Mean Absolute Error (MAE): 0.1796052667950521
# R-squared (R2) Score: 0.8839830868080707

# %%
data={
    'age':[50,18,61],
    'sex':[1,0,0],
    'bmi':[31,31.9,29.1],
    'children':[3,0,0],
    'smoker':[0,0,1],
    'region':[3,4,3]
}
# 50	male	31.0	3	no	northwest	10600.55
# 18	female	31.9	0	no	northeast	2205.98
# 61	female	29.1	0	yes	northwest	29141.36
# ['female' 'male']
# ['yes' 'no']
# ['southwest' 'southeast' 'northwest' 'northeast']
newdf=pd.DataFrame(data,index=[0,1,2])
newdf
# Out:
#    age  sex   bmi  children  smoker  region
# 0   50    1  31.0         3       0       3
# 1   18    0  31.9         0       0       4
# 2   61    0  29.1         0       1       3

# %%
pred = final_model.predict(newdf)
pred_original_scale = np.expm1(pred)
print(pred_original_scale)
# Out:
# [11203.01475561  3021.8991057  27408.04911063]

# %%
import joblib
joblib.dump(final_model,'random.pkl')
# Out:
# ['random.pkl']

# %%
model = joblib.load('random_forest.pkl')

# %%
pred= model.predict(newdf)
pred_original_scale = np.expm1(pred)
print(pred_original_scale)
# Out:
# [11203.01475561  3021.8991057  27408.04911063]
